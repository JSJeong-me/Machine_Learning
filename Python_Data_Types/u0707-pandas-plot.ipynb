# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Machine_Learning/blob/main/Python_Data_Types/u0707-pandas-plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
mu = 168 #mean
sigma = 5 #stddev
sample = 250
np.random.seed(0)
height_f = np.random.normal(mu, sigma, sample).astype(int)

# %%
height_f

# %%
mu = 176 #mean
sigma = 6 #stddev
sample = 250
np.random.seed(1)
height_m = np.random.normal(mu, sigma, sample).astype(int)

# %%
height_m

# %%
gym = pd.DataFrame({'height_m': height_m, 'height_f': height_f})

# %%
gym.head()
# Out:
#    height_m  height_f
# 0       185       176
# 1       172       170
# 2       172       172
# 3       169       179
# 4       181       177

# %%
gym.plot()

# %%
gym.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0603631b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0603645110>]],
#       dtype=object)

# %%
gym.groupby('height_f').count().plot()

# %%
gym.groupby('height_m').count().hist()

# %%
gym.groupby('height_f').count().plot.bar()

# %%
gym.groupby('height_m').count().plot.bar()

# %%
gym.groupby('height_m').count().plot.bar()

# %%
gym.hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f060266d690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0602612b10>]],
#       dtype=object)

# %%
gym.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0602f06950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0602eb27d0>]],
#       dtype=object)

# %%
gym.plot.hist(bins=30, alpha=0.7)

# %%
gym.plot.hist(bins=30)
