# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Machine_Learning/blob/main/ML/Part1-classN-deeplearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/a-single-neuron).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In the tutorial we learned about the building blocks of neural networks: *linear units*. We saw that a model of just one linear unit will fit a linear function to a dataset (equivalent to linear regression). In this exercise, you'll build a linear model and get some practice working with models in Keras.
#
# Before you get started, run the code cell below to set everything up.

# %% [markdown]
# The *Red Wine Quality* dataset consists of physiochemical measurements from about 1600 Portuguese red wines.  Also included is a quality rating for each wine from blind taste-tests.
#
# First, run the next cell to display the first few rows of this dataset.

# %%
import pandas as pd
from IPython.display import display

red_wine = pd.read_csv('winequality-red.csv')

# %%
# Create training and validation splits
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)
display(df_train.head(4))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1109                 27.0                  66.0  0.99820  3.17       0.76
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 1002                 13.0                  27.0  0.99516  3.26       0.84
# 487                   5.0                  14.0  0.99820  3.17       0.42
#
#       alcohol  quality
# 1109     10.8        6
# 1032      9.6        5
# 1002     11.7        7
# 487      10.0        6

# %%
# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# %%
# Split features and target
X_train = df_train.drop('quality', axis=1)
X_valid = df_valid.drop('quality', axis=1)
y_train = df_train['quality']
y_valid = df_valid['quality']

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[11]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               6144
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 531,969
# Trainable params: 531,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks

early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %%
model.compile(
    optimizer='adam', # sgd, rmsprop, adam
    loss='mae',
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=256,
    epochs=600,
    callbacks=[early_stopping], # put your callbacks in a list
    verbose=1,  # turn off training log
)
# Out:
# Epoch 1/600
# 5/5 [==============================] - 2s 125ms/step - loss: 0.3640 - val_loss: 0.1592
# Epoch 2/600
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1455 - val_loss: 0.1195
# Epoch 3/600
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1451 - val_loss: 0.1230
# Epoch 4/600
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1337 - val_loss: 0.1847
# Epoch 5/600
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1363 - val_loss: 0.1274
# Epoch 6/600
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1264 - val_loss: 0.1289
# Epoch 7/600
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1416 - val_loss: 0.1192
# Epoch 8/600
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1230 - val_loss: 0.1158
# Epoch 9/600
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1292 - val_loss: 0.1076
# Epoch 10/600
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1102 - val_loss: 0.1641
# Epoch 11/600
# 5/5 [==============================] - 0s 42ms/step - loss: 0.1325 - val_loss: 0.1208
# Epoch 12/600
# 5/5 [==============================] - 0s 71ms/step - loss: 0.1174 - val_loss: 0.1093
# Epoch 13/600
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1230 - val_loss: 0.1067
# Epoch 14/600
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1195 - val_loss: 0.1112
# Epoch 15/600
# 5/5 [==============================] - 0s 67ms/step - loss: 0.1078 - val_loss: 0.1782
# Epoch 16/600
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1227 - val_loss: 0.1156
# Epoch 17/600
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1188 - val_loss: 0.1177
# Epoch 18/600
# 5/5 [==============================] - 0s 41ms/step - loss: 0.1173 - val_loss: 0.1006
# Epoch 19/600
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1106 - val_loss: 0.1532
# Epoch 20/600
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1119 - val_loss: 0.1020
# Epoch 21/600
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1098 - val_loss: 0.1322
# Epoch 22/600
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1177 - val_loss: 0.1025
# Epoch 23/600
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1040 - val_loss: 0.1465
# Epoch 24/600
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1154 - val_loss: 0.1007
# Epoch 25/600
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1119 - val_loss: 0.1077
# Epoch 26/600
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0990 - val_loss: 0.1604
# Epoch 27/600
# 5/5 [==============================] - 0s 45ms/step - loss: 0.1157 - val_loss: 0.1210
# Epoch 28/600
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1141 - val_loss: 0.1101
# Epoch 29/600
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0955 - val_loss: 0.0977
# Epoch 30/600
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1226 - val_loss: 0.1092
# Epoch 31/600
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0970 - val_loss: 0.1236
# Epoch 32/600
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1109 - val_loss: 0.0991
# Epoch 33/600
# 5/5 [==============================] - 0s 39ms/step - loss: 0.1074 - val_loss: 0.1188
# Epoch 34/600
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0961 - val_loss: 0.0976
# Epoch 35/600
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1157 - val_loss: 0.1288
# Epoch 36/600
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0978 - val_loss: 0.1110
# Epoch 37/600
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1041 - val_loss: 0.1050
# Epoch 38/600
# 5/5 [==============================] - 0s 65ms/step - loss: 0.1000 - val_loss: 0.1052
# Epoch 39/600
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1058 - val_loss: 0.1044
# Epoch 40/600
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0985 - val_loss: 0.0964
# Epoch 41/600
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0988 - val_loss: 0.1172
# Epoch 42/600
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1041 - val_loss: 0.1023
# Epoch 43/600
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1043 - val_loss: 0.1254
# Epoch 44/600
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0976 - val_loss: 0.0961
# Epoch 45/600
# 5/5 [==============================] - 0s 65ms/step - loss: 0.1030 - val_loss: 0.1031
# Epoch 46/600
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0939 - val_loss: 0.0976
# Epoch 47/600
# 5/5 [==============================] - 0s 63ms/step - loss: 0.1008 - val_loss: 0.1282
# Epoch 48/600
# 5/5 [==============================] - 0s 69ms/step - loss: 0.1073 - val_loss: 0.1006
# Epoch 49/600
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0958 - val_loss: 0.1049
# Epoch 50/600
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0972 - val_loss: 0.0984
# Epoch 51/600
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0852 - val_loss: 0.1065
# Epoch 52/600
# 5/5 [==============================] - 0s 76ms/step - loss: 0.1050 - val_loss: 0.1049
# Epoch 53/600
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0963 - val_loss: 0.0956
# Epoch 54/600
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0849 - val_loss: 0.1461
# Epoch 55/600
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1029 - val_loss: 0.1009
# Epoch 56/600
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0937 - val_loss: 0.1086
# Epoch 57/600
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0941 - val_loss: 0.1052
# Epoch 58/600
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0913 - val_loss: 0.0953
# Epoch 59/600
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0937 - val_loss: 0.0956
# Epoch 60/600
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0899 - val_loss: 0.1028
# Epoch 61/600
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0929 - val_loss: 0.1087
# Epoch 62/600
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0897 - val_loss: 0.0970
# Epoch 63/600
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0916 - val_loss: 0.0936
# Epoch 64/600
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0898 - val_loss: 0.1277
# Epoch 65/600
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0908 - val_loss: 0.1016
# Epoch 66/600
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0945 - val_loss: 0.0975
# Epoch 67/600
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0925 - val_loss: 0.1025
# Epoch 68/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0858 - val_loss: 0.1040
# Epoch 69/600
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0913 - val_loss: 0.0953
# Epoch 70/600
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0918 - val_loss: 0.0960
# Epoch 71/600
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0899 - val_loss: 0.1175
# Epoch 72/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0857 - val_loss: 0.1017
# Epoch 73/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0914 - val_loss: 0.1052
# Epoch 74/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0843 - val_loss: 0.1159
# Epoch 75/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0921 - val_loss: 0.1191
# Epoch 76/600
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0901 - val_loss: 0.0970
# Epoch 77/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0889 - val_loss: 0.0953
# Epoch 78/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0808 - val_loss: 0.0982
# Epoch 79/600
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0846 - val_loss: 0.0976
# Epoch 80/600
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0895 - val_loss: 0.0996
# Epoch 81/600
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0762 - val_loss: 0.0959
# Epoch 82/600
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0909 - val_loss: 0.1064
# Epoch 83/600
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0886 - val_loss: 0.0996

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot();
print("Minimum validation loss: {}".format(history_df['val_loss'].min()))
# Out:
# Minimum validation loss: 0.09358664602041245

# %% [markdown]
# ![다운로드 (2).png](data:image/png;base64,...)

# %% [markdown]
# ![다운로드.png](data:image/png;base64,...)

# %% [markdown]
# ![다운로드 (1).png](data:image/png;base64,...)
