# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Machine_Learning/blob/main/ML/6_wine_0808-uni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
import pandas as pd

# %%
red_wine = pd.read_csv('winequality-red.csv')

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
red_wine.corr(method='pearson')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df_train = red_wine.sample(frac=0.7, random_state=0)
df_valid = red_wine.drop(df_train.index)

# %%
df_train.shape
# Out:
# (1119, 12)

# %%
df_valid.shape
# Out:
# (480, 12)

# %%
df_train.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 640             9.9              0.54         0.45             2.3      0.071
# 104             7.2              0.49         0.24             2.2      0.070
# 815            10.8              0.45         0.33             2.5      0.099
# 998             8.9              0.84         0.34             1.4      0.050
# 1075            9.1              0.25         0.34             2.0      0.071
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 640                  16.0                  40.0  0.99910  3.39       0.62
# 104                   5.0                  36.0  0.99600  3.33       0.48
# 815                  20.0                  38.0  0.99818  3.24       0.71
# 998                   4.0                  10.0  0.99554  3.12       0.48
# 1075                 45.0                  67.0  0.99769  3.44       0.86
#
#       alcohol  quality
# 640       9.4        5
# ...

# %%
# Scale to [0, 1]
max_ = df_train.max(axis=0)
min_ = df_train.min(axis=0)
df_train = (df_train - min_) / (max_ - min_)
df_valid = (df_valid - min_) / (max_ - min_)

# %%
df_train.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1119.000000       1119.000000  1119.000000     1119.000000
# mean        0.327339          0.278490     0.341489        0.123806
# std         0.155359          0.119094     0.246080        0.098173
# min         0.000000          0.000000     0.000000        0.000000
# 25%         0.221239          0.191781     0.113924        0.076923
# 50%         0.292035          0.273973     0.316456        0.100000
# 75%         0.407080          0.351027     0.544304        0.130769
# max         1.000000          1.000000     1.000000        1.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1119.000000          1119.000000           1119.000000  1119.000000
# mean      0.091692             0.206057              0.142169     0.508681
# std       0.076507             0.141832              0.116359     0.143223
# ...

# %%
keras_layer = [
    layers.Dense(units=150, input_shape=[3]),
    layers.Dense(units=300, activation='relu'),
    layers.Dense(units=350, activation='relu'),
    layers.Dense(units=500, activation='relu'),
    layers.Dense(units=200, activation='relu'),
    layers.Dense(units=50, activation='relu'),
    layers.Dense(units=1, activation='sigmoid')
]

# %%
# Create a network with 1 linear unit
model = keras.Sequential(keras_layer)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=None)

# %%
model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=None)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 150)               600
#
#  dense_1 (Dense)             (None, 300)               45300
#
#  dense_2 (Dense)             (None, 350)               105350
#
#  dense_3 (Dense)             (None, 500)               175500
#
#  dense_4 (Dense)             (None, 200)               100200
#
#  dense_5 (Dense)             (None, 50)                10050
#
#  dense_6 (Dense)             (None, 1)                 51
#
# ...
# Total params: 437,051
# Trainable params: 437,051
# Non-trainable params: 0
# _________________________________________________________________
